# %%
import pandas as pd
import numpy as np
from pandas.io.json import json_normalize
import os

# %%
def func(x):
        return pd.Series(json_normalize(x).to_dict('records')[0])

# %%
def load_df(csv_path='../input/train.csv', nrows=None):
    JSON_COLUMNS = ['device', 'geoNetwork', 'totals', 'trafficSource']
    
    df = pd.read_csv(csv_path, 
                     converters={column: json.loads for column in JSON_COLUMNS}, 
                     dtype={'fullVisitorId': 'str'}, # Important!!
                     nrows=nrows)
    
    for column in JSON_COLUMNS:
        column_as_df = json_normalize(df[column])
#         column_as_df = df[column].apply(func)
        column_as_df.columns = [f"{column}.{subcolumn}" for subcolumn in column_as_df.columns]
        df = df.drop(column, axis=1).merge(column_as_df, right_index=True, left_index=True)
    print(f"Loaded {os.path.basename(csv_path)}. Shape: {df.shape}")
    return df

# %%
# train_base_dataset = load_df("C:\\Sridhar\\AI_ML\\Algorithms\\datasets\\ga-customer-revenue-prediction\\train_v2.csv")

# %%
train_base_dataset = pd.read_csv("C:\\Sridhar\\AI_ML\\Algorithms\\datasets\\ga-customer-revenue-prediction\\train_v2.csv")
# Out:
# C:\Users\srivutta\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3057: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
train_base_dataset.shape
# Out:
# (1708337, 13)

# %%
train_base_dataset.head()
# Out:
#   channelGrouping                              customDimensions      date  \
# 0  Organic Search             [{'index': '4', 'value': 'EMEA'}]  20171016
# 1        Referral    [{'index': '4', 'value': 'North America'}]  20171016
# 2          Direct    [{'index': '4', 'value': 'North America'}]  20171016
# 3  Organic Search             [{'index': '4', 'value': 'EMEA'}]  20171016
# 4  Organic Search  [{'index': '4', 'value': 'Central America'}]  20171016
#
#                                               device        fullVisitorId  \
# 0  {"browser": "Firefox", "browserVersion": "not ...  3162355547410993243
# 1  {"browser": "Chrome", "browserVersion": "not a...  8934116514970143966
# 2  {"browser": "Chrome", "browserVersion": "not a...  7992466427990357681
# 3  {"browser": "Chrome", "browserVersion": "not a...  9075655783635761930
# 4  {"browser": "Chrome", "browserVersion": "not a...  6960673291025684308
#
#                                           geoNetwork  \
# ...

# %%
test_base_dataset = pd.read_csv("C:\\Sridhar\\AI_ML\\Algorithms\\datasets\\ga-customer-revenue-prediction\\test_v2.csv")
# Out:
# C:\Users\srivutta\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3057: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
test_base_dataset.shape
# Out:
# (401589, 13)

# %%
training_sample_dataset = pd.read_csv("C:\\Sridhar\\AI_ML\\Algorithms\\datasets\\ga-customer-revenue-prediction\\training_sample.csv")

# %%
training_sample_dataset = training_sample_dataset[0:1000]

# %%
training_sample_dataset.shape
# Out:
# (1000, 14)

# %%
numerical_columns=training_sample_dataset.mean().index

# %%
numerical_columns
# Out:
# Index(['Unnamed: 0', 'date', 'fullVisitorId', 'visitId', 'visitNumber',
#        'visitStartTime'],
#       dtype='object')

# %%
catagorical_column = []
for i in training_sample_dataset.columns:
    if i not in numerical_columns:
        catagorical_column.append(i)
print(catagorical_column)
# Out:
# ['channelGrouping', 'customDimensions', 'device', 'geoNetwork', 'hits', 'socialEngagementType', 'totals', 'trafficSource']

# %%
numerical_descrete = []
numerical_continuous = []
for i in training_sample_dataset[numerical_columns]:
    if training_sample_dataset[i].nunique() >= 20:
        numerical_continuous.append(i)
    else:
        numerical_descrete.append(i)

# %%
catogorical_text = []
catogorical_descrete = []
for i in training_sample_dataset[catagorical_column]:
    if training_sample_dataset[i].nunique()>47:
        catogorical_text.append(i)
    else:
        catogorical_descrete.append(i)

# %%
catogorical_descrete
# Out:
# ['channelGrouping', 'customDimensions', 'device', 'socialEngagementType']

# %%
for i in numerical_continuous:
    training_sample_dataset[i].fillna(training_sample_dataset[i].median(),inplace=True)

for i in numerical_descrete:
    training_sample_dataset[i].fillna(training_sample_dataset[i].mode().values[0],inplace=True)
    
for i in catogorical_descrete:
    training_sample_dataset[i].fillna(training_sample_dataset[i].mode().values[0],inplace=True)
for i in catogorical_text:
    if i == 'geoNetwork':
        training_sample_dataset[i].fillna('{"continent": "Americas", "subContinent": "Northern America", "country": "United States", "region": "California", "metro": "San Francisco-Oakland-San Jose CA", "city": "Sunnyvale", "cityId": "not available in demo dataset", "networkDomain": "comcastbusiness.net", "latitude": "not available in demo dataset", "longitude": "not available in demo dataset", "networkLocation": "not available in demo dataset"}',inplace=True)
    if i == 'totals':
        training_sample_dataset[i].fillna('{"visits": "1", "hits": "4", "pageviews": "4", "timeOnSite": "46", "newVisits": "1", "sessionQualityDim": "1"}',inplace=True)
    if i == 'totals':
        training_sample_dataset[i].fillna('{"campaign": "(not set)", "source": "(direct)", "medium": "(none)", "adwordsClickInfo": {"criteriaParameters": "not available in demo dataset"}, "isTrueDirect": true}',inplace=True)

# %%
training_sample_dataset.head()
# Out:
#   channelGrouping                              customDimensions      date  \
# 0  Organic Search             [{'index': '4', 'value': 'EMEA'}]  20171016
# 1        Referral    [{'index': '4', 'value': 'North America'}]  20171016
# 2          Direct    [{'index': '4', 'value': 'North America'}]  20171016
# 3  Organic Search             [{'index': '4', 'value': 'EMEA'}]  20171016
# 4  Organic Search  [{'index': '4', 'value': 'Central America'}]  20171016
#
#                                               device        fullVisitorId  \
# 0  {"browser": "Firefox", "browserVersion": "not ...  3162355547410993243
# 1  {"browser": "Chrome", "browserVersion": "not a...  8934116514970143966
# 2  {"browser": "Chrome", "browserVersion": "not a...  7992466427990357681
# 3  {"browser": "Chrome", "browserVersion": "not a...  9075655783635761930
# 4  {"browser": "Chrome", "browserVersion": "not a...  6960673291025684308
#
# ...

# %%
training_sample_dataset.drop('Unnamed: 0',axis=1,inplace=True)

# %%
training_sample_dataset.to_csv("C:\\Sridhar\\AI_ML\\Algorithms\\datasets\\ga-customer-revenue-prediction\\testingMaa.csv")

# %%
training_sample_dataset_1 = load_df("C:\\Sridhar\\AI_ML\\Algorithms\\datasets\\ga-customer-revenue-prediction\\testingMaa.csv")
# Out:
# Loaded testingMaa.csv. Shape: (1000, 61)

# %%
training_sample_dataset_1.drop('hits',axis=1,inplace=true)
# Out:
#    Unnamed: 0  Unnamed: 0.1 channelGrouping  \
# 0           0             0  Organic Search
# 1           1             1        Referral
# 2           2             2          Direct
# 3           3             3  Organic Search
# 4           4             4  Organic Search
#
#                                customDimensions      date  \
# 0             [{'index': '4', 'value': 'EMEA'}]  20171016
# 1    [{'index': '4', 'value': 'North America'}]  20171016
# 2    [{'index': '4', 'value': 'North America'}]  20171016
# 3             [{'index': '4', 'value': 'EMEA'}]  20171016
# 4  [{'index': '4', 'value': 'Central America'}]  20171016
#
#          fullVisitorId                                               hits  \
# 0  3162355547410993243  [{'hitNumber': '1', 'time': '0', 'hour': '17',...
# 1  8934116514970143966  [{'hitNumber': '1', 'time': '0', 'hour': '10',...
# 2  7992466427990357681  [{'hitNumber': '1', 'time': '0', 'hour': '17',...
# ...

# %%
training_sample_dataset_1.drop(['Unnamed: 0','Unnamed: 0.1'],axis=1,inplace=True)

# %%
training_sample_dataset_1.head()
# Out:
#   channelGrouping                              customDimensions      date  \
# 0  Organic Search             [{'index': '4', 'value': 'EMEA'}]  20171016
# 1        Referral    [{'index': '4', 'value': 'North America'}]  20171016
# 2          Direct    [{'index': '4', 'value': 'North America'}]  20171016
# 3  Organic Search             [{'index': '4', 'value': 'EMEA'}]  20171016
# 4  Organic Search  [{'index': '4', 'value': 'Central America'}]  20171016
#
#          fullVisitorId  socialEngagementType     visitId  visitNumber  \
# 0  3162355547410993243  Not Socially Engaged  1508198450            1
# 1  8934116514970143966  Not Socially Engaged  1508176307            6
# 2  7992466427990357681  Not Socially Engaged  1508201613            1
# 3  9075655783635761930  Not Socially Engaged  1508169851            1
# 4  6960673291025684308  Not Socially Engaged  1508190552            1
#
#    visitStartTime device.browser             device.browserSize  ...  \
# ...

# %%
training_sample_dataset = load_df("C:\\Sridhar\\AI_ML\\Algorithms\\datasets\\ga-customer-revenue-prediction\\training_sample_1000.csv")
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-27-278d29df0511> in <module>
# ----> 1 training_sample_dataset = load_df("C:\\Sridhar\\AI_ML\\Algorithms\\datasets\\ga-customer-revenue-prediction\\training_sample_1000.csv")
#
# <ipython-input-26-24284b139400> in load_df(csv_path, nrows)
#       5                      converters={column: json.loads for column in JSON_COLUMNS},
#       6                      dtype={'fullVisitorId': 'str'}, # Important!!
# ----> 7                      nrows=nrows)
#       8
#       9     for column in JSON_COLUMNS:
#
# ...

# %%
training_sample_dataset.head(5)
# Out:
#    Unnamed: 0 channelGrouping                              customDimensions  \
# 0           0  Organic Search             [{'index': '4', 'value': 'EMEA'}]
# 1           1        Referral    [{'index': '4', 'value': 'North America'}]
# 2           2          Direct    [{'index': '4', 'value': 'North America'}]
# 3           3  Organic Search             [{'index': '4', 'value': 'EMEA'}]
# 4           4  Organic Search  [{'index': '4', 'value': 'Central America'}]
#
#        date        fullVisitorId  \
# 0  20171016  3162355547410993243
# 1  20171016  8934116514970143966
# 2  20171016  7992466427990357681
# 3  20171016  9075655783635761930
# 4  20171016  6960673291025684308
#
#                                                 hits  socialEngagementType  \
# 0  [{'hitNumber': '1', 'time': '0', 'hour': '17',...  Not Socially Engaged
# 1  [{'hitNumber': '1', 'time': '0', 'hour': '10',...  Not Socially Engaged
# 2  [{'hitNumber': '1', 'time': '0', 'hour': '17',...  Not Socially Engaged
# ...

# %%
# df_train = train_base_dataset[0:20000]
# df_test = test_base_dataset[0:20000]

# %%
df_train.shape,df_test.shape
# Out:
# ((20000, 13), (20000, 13))

# %%
df_train.columns
# Out:
# Index(['channelGrouping', 'customDimensions', 'date', 'device',
#        'fullVisitorId', 'geoNetwork', 'hits', 'socialEngagementType', 'totals',
#        'trafficSource', 'visitId', 'visitNumber', 'visitStartTime'],
#       dtype='object')

# %%
df_test.columns
# Out:
# Index(['channelGrouping', 'customDimensions', 'date', 'device',
#        'fullVisitorId', 'geoNetwork', 'hits', 'socialEngagementType', 'totals',
#        'trafficSource', 'visitId', 'visitNumber', 'visitStartTime'],
#       dtype='object')

# %%
 def memoryManagement(base_dataset):
    """ iterate through all the columns of a dataframe and modify the data type
        to reduce memory usage.        
    """
    df=base_dataset
    start_mem = df.memory_usage().sum() / 1024**2
    print('Memory usage of dataframe is {:.2f} MB'.format(start_mem))

    for col in df.columns:
        col_type = df[col].dtype

        if col_type != object:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)  
            else:
                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)
        else:
            df[col] = df[col].astype('category')

    end_mem = df.memory_usage().sum() / 1024**2
    print('Memory usage after optimization is: {:.2f} MB'.format(end_mem))
    print('Decreased by {:.1f}%'.format(100 * (start_mem - end_mem) / start_mem))    
    return df

# %%
df_train = memoryManagement(df_train)

# %%
df_test = memoryManagement(df_test)

# %%
(df_train.isna().sum()/df_train.shape[0])*100

# %%
(df_test.isna().sum()/df_test.shape[0])*100

# %%
def null_values(base_dataset):
    print(base_dataset.isna().sum())
    # null value percentage     
    null_value_table=(base_dataset.isna().sum()/base_dataset.shape[0])*100
    # null value percentage beyond threshold drop , else treat the columns 
    
    retained_columns=null_value_table[null_value_table<int(input())].index
    #if any variable as null value greater than input(like 30% of the data) 
    #value than those variable are consider as drop
    drop_columns=null_value_table[null_value_table>int(input())].index
    base_dataset.drop(drop_columns,axis=1,inplace=True)
    len(base_dataset.isna().sum().index)
    cont=base_dataset.describe().columns
    cat=[i for i in base_dataset.columns if i not in base_dataset.describe().columns]
    for i in cat:
        base_dataset[i].fillna(base_dataset[i].value_counts().index[0],inplace=True)
    for i in cont:
        base_dataset[i].fillna(base_dataset[i].median(),inplace=True)
    print(base_dataset.isna().sum())
    return base_dataset,cat,cont

# %%
df_train_data,df_train_catagorical_columns,df_train_continuous_columns = null_values(df_train)

# %%
df_train_data.shape,len(df_train_catagorical_columns),len(df_train_continuous_columns)

# %%
df_test_data,df_test_catagorical_columns,df_test_continuous_columns = null_values(df_test)

# %%
df_test_data.shape,len(df_test_catagorical_columns),len(df_test_continuous_columns)

# %%
training_sample_dataset.mean().index
# Out:
# Index(['date', 'visitId', 'visitNumber', 'visitStartTime'], dtype='object')
