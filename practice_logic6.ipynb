# %%
x = [1,2,3]

# %%
for i in x:
    print(i)
# Out:
# 1
# 2
# 3

# %%
x = "data science"
for i in x:
    print(i)
# Out:
# d
# a
# t
# a
#
# s
# c
# i
# e
# n
# c
# e

# %%
x = "data science".split()
for i in x:
    print(i)
# Out:
# data
# science

# %%
text="The speculations in Haryana finally comes to an end as JJP and BJP forge an alliance to form government in Haryana. BJP, who gained 40 seats in the recently concluded Assembly Elections 2019, needed external support for a majority and they found a willing partner in JJP. Dushyant Chautala, the founder of JJP has been offered the post of Deputy Chief Minister. The announcement of the alliance was made by Union Home Minister and BJP leader Amit Shah.09:25"

# %%
text
# Out:
# 'The speculations in Haryana finally comes to an end as JJP and BJP forge an alliance to form government in Haryana. BJP, who gained 40 seats in the recently concluded Assembly Elections 2019, needed external support for a majority and they found a willing partner in JJP. Dushyant Chautala, the founder of JJP has been offered the post of Deputy Chief Minister. The announcement of the alliance was made by Union Home Minister and BJP leader Amit Shah.09:25'

# %%
x=[]
for i in text:
    if (i.lower not in x) and (i.isalpha()):
        x.append(i)

# %%
len(x)
# Out:
# 0

# %%
print(x)
# Out:
# ['T', 'h', 'e', 's', 'p', 'e', 'c', 'u', 'l', 'a', 't', 'i', 'o', 'n', 's', 'i', 'n', 'H', 'a', 'r', 'y', 'a', 'n', 'a', 'f', 'i', 'n', 'a', 'l', 'l', 'y', 'c', 'o', 'm', 'e', 's', 't', 'o', 'a', 'n', 'e', 'n', 'd', 'a', 's', 'J', 'J', 'P', 'a', 'n', 'd', 'B', 'J', 'P', 'f', 'o', 'r', 'g', 'e', 'a', 'n', 'a', 'l', 'l', 'i', 'a', 'n', 'c', 'e', 't', 'o', 'f', 'o', 'r', 'm', 'g', 'o', 'v', 'e', 'r', 'n', 'm', 'e', 'n', 't', 'i', 'n', 'H', 'a', 'r', 'y', 'a', 'n', 'a', 'B', 'J', 'P', 'w', 'h', 'o', 'g', 'a', 'i', 'n', 'e', 'd', 's', 'e', 'a', 't', 's', 'i', 'n', 't', 'h', 'e', 'r', 'e', 'c', 'e', 'n', 't', 'l', 'y', 'c', 'o', 'n', 'c', 'l', 'u', 'd', 'e', 'd', 'A', 's', 's', 'e', 'm', 'b', 'l', 'y', 'E', 'l', 'e', 'c', 't', 'i', 'o', 'n', 's', 'n', 'e', 'e', 'd', 'e', 'd', 'e', 'x', 't', 'e', 'r', 'n', 'a', 'l', 's', 'u', 'p', 'p', 'o', 'r', 't', 'f', 'o', 'r', 'a', 'm', 'a', 'j', 'o', 'r', 'i', 't', 'y', 'a', 'n', 'd', 't', 'h', 'e', 'y', 'f', 'o', 'u', 'n', 'd', 'a', 'w', 'i', 'l', 'l
# ...

# %%
for i in x:
    print(i,text.lower().count(i)/len(text))
# Out:
# T 0.0
# h 0.037199124726477024
# e 0.0962800875273523
# s 0.037199124726477024
# p 0.0262582056892779
# e 0.0962800875273523
# c 0.024070021881838075
# u 0.02188183807439825
# l 0.0350109409190372
# a 0.08096280087527352
# t 0.05689277899343545
# i 0.0437636761487965
# o 0.05032822757111598
# n 0.08315098468271334
# s 0.037199124726477024
# i 0.0437636761487965
# n 0.08315098468271334
# H 0.0
# a 0.08096280087527352
# r 0.037199124726477024
# y 0.02188183807439825
# a 0.08096280087527352
# n 0.08315098468271334
# a 0.08096280087527352
# f 0.0262582056892779
# i 0.0437636761487965
# n 0.08315098468271334
# a 0.08096280087527352
# l 0.0350109409190372
# l 0.0350109409190372
# y 0.02188183807439825
# c 0.024070021881838075
# o 0.05032822757111598
# m 0.024070021881838075
# e 0.0962800875273523
# s 0.037199124726477024
# t 0.05689277899343545
# o 0.05032822757111598
# a 0.08096280087527352
# n 0.08315098468271334
# e 0.0962800875273523
# n 0.08315098468271334
# d 0.0350109409190372
# ...

# %%
for i in x:
    print(i,text.lower().count(i)/len(text))
