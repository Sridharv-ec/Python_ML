# %% [markdown]
# ### base model - with only number variables

# %%
import pandas as pd

# %%
import numpy as np

# %%
df_train=pd.read_csv("C:\\Sridhar\\AI_ML\\Algorithms\\datasets\\HomePrices\\train.csv")
df_holdout=pd.read_csv("C:\\Sridhar\\AI_ML\\Algorithms\\datasets\\HomePrices\\test.csv")

# %%
df_train.shape,df_holdout.shape
# Out:
# ((1460, 81), (1459, 80))

# %%
df_train=df_train[df_train.describe().columns]

# %%
df_train.head()
# Out:
#    Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0   1          60         65.0     8450            7            5       2003
# 1   2          20         80.0     9600            6            8       1976
# 2   3          60         68.0    11250            7            5       2001
# 3   4          70         60.0     9550            7            5       1915
# 4   5          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  ...  WoodDeckSF  OpenPorchSF  \
# 0          2003       196.0         706  ...           0           61
# 1          1976         0.0         978  ...         298            0
# 2          2002       162.0         486  ...           0           42
# 3          1970         0.0         216  ...           0           35
# 4          2000       350.0         655  ...         192           84
#
#    EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  MiscVal  MoSold  YrSold  \
# ...

# %%
df_train.drop('Id',axis=1,inplace=True)

# %%
y=df_train['SalePrice'].values
x=df_train.drop('SalePrice',axis=1)

# %%
x=x.values

# %%
df_train.shape
# Out:
# (1460, 37)

# %%
df_train.fillna(20,inplace=True)

# %%
from numpy.linalg import inv

# %%
beta_coeff=np.dot((np.dot(x.T,inv(np.dot(x,x.T)))),y)

# %%
beta_coeff
# Out:
# array([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan])

# %%
pd.set_option('display.float_format', '{:.2f}'.format)

# %%
pd.DataFrame([beta_coeff,x.columns]).T
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-cce5c05189dc> in <module>
# ----> 1 pd.DataFrame([beta_coeff,x.columns]).T
#
# AttributeError: 'numpy.ndarray' object has no attribute 'columns'

# %% [markdown]
# ### base model - with all variables variables

# %%
import pandas as pd

# %%
import numpy as np

# %%
df_train=pd.read_csv("C:\\Users\\hh\\Desktop\\datasets\\train.csv")
df_holdout=pd.read_csv("C:\\Users\\hh\\Desktop\\datasets\\test.csv")

# %%
df_train.shape,df_holdout.shape
# Out:
# ((1460, 81), (1459, 80))

# %%
df_train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL        65.00     8450   Pave   NaN      Reg
# 1   2          20       RL        80.00     9600   Pave   NaN      Reg
# 2   3          60       RL        68.00    11250   Pave   NaN      IR1
# 3   4          70       RL        60.00     9550   Pave   NaN      IR1
# 4   5          60       RL        84.00    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
from sklearn.preprocessing import LabelEncoder
for i in df_train.describe(include='object').columns:
    le=LabelEncoder()
    le.fit(df_train[i].astype(str))
    t=le.transform(df_train[i].astype(str))
    df_train[i]=t

# %%
df_train.head()
# Out:
#    Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  LotShape  \
# 0   1          60         3        65.00     8450       1      2         3
# 1   2          20         3        80.00     9600       1      2         3
# 2   3          60         3        68.00    11250       1      2         0
# 3   4          70         3        60.00     9550       1      2         0
# 4   5          60         3        84.00    14260       1      2         0
#
#    LandContour  Utilities  ...  PoolArea  PoolQC  Fence  MiscFeature  MiscVal  \
# 0            3          0  ...         0       3      4            4        0
# 1            3          0  ...         0       3      4            4        0
# 2            3          0  ...         0       3      4            4        0
# 3            3          0  ...         0       3      4            4        0
# 4            3          0  ...         0       3      4            4        0
#
# ...

# %%
df_train.drop('Id',axis=1,inplace=True)

# %%
df_train.fillna(20,inplace=True)

# %%
y=df_train['SalePrice'].values
x=df_train.drop('SalePrice',axis=1)

# %%
x.shape
# Out:
# (1460, 79)

# %%
x=x.values

# %%
df_train.shape
# Out:
# (1460, 80)

# %%
from numpy.linalg import inv

# %%
beta_coeff=np.dot((np.dot(x.T,inv(np.dot(x,x.T)))),y)

# %%
pd.set_option('display.float_format', '{:.2f}'.format)

# %%
pd.DataFrame([beta_coeff,x.columns]).T
# Out:
#             0              1
# 0    -4167.91     MSSubClass
# 1  -149965.46       MSZoning
# 2    -8033.11    LotFrontage
# 3     6012.52        LotArea
# 4  1043761.97         Street
# 5   237057.61          Alley
# 6   101008.71       LotShape
# 7  -144423.18    LandContour
# 8  2420806.29      Utilities
# 9   -11890.04      LotConfig
# 10 -247959.77      LandSlope
# 11  -24060.56   Neighborhood
# 12   16784.01     Condition1
# 13 -367816.57     Condition2
# 14  -21279.46       BldgType
# 15   28951.35     HouseStyle
# 16  -73617.68    OverallQual
# 17   79351.85    OverallCond
# 18   -8100.66      YearBuilt
# 19   10486.43   YearRemodAdd
# 20 -124219.27      RoofStyle
# 21  -14929.98       RoofMatl
# 22   94050.24    Exterior1st
# 23  -97325.35    Exterior2nd
# 24   65356.64     MasVnrType
# 25    1483.00     MasVnrArea
# 26   78017.01      ExterQual
# 27   47714.35      ExterCond
# 28   66401.44     Foundation
# 29 -119398.96       BsmtQual
# ..        ...            ...
# ...

# %%
df_holdout.shape
# Out:
# (1459, 80)

# %%
df_holdout.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH        80.00    11622   Pave   NaN      Reg
# 1  1462          20       RL        81.00    14267   Pave   NaN      IR1
# 2  1463          60       RL        74.00    13830   Pave   NaN      IR1
# 3  1464          60       RL        78.00     9978   Pave   NaN      IR1
# 4  1465         120       RL        43.00     5005   Pave   NaN      IR1
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence MiscFeature  \
# 0         Lvl    AllPub  ...         120        0    NaN  MnPrv         NaN
# 1         Lvl    AllPub  ...           0        0    NaN    NaN        Gar2
# 2         Lvl    AllPub  ...           0        0    NaN  MnPrv         NaN
# 3         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 4         HLS    AllPub  ...         144        0    NaN    NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
from sklearn.preprocessing import LabelEncoder
for i in df_holdout.describe(include='object').columns:
    le=LabelEncoder()
    le.fit(df_holdout[i].astype(str))
    t=le.transform(df_holdout[i].astype(str))
    df_holdout[i]=t

# %%
df_holdout.fillna(20,inplace=True)

# %%
df_holdout.head()
# Out:
#      Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  LotShape  \
# 0  1461          20         2        80.00    11622       1      2         3
# 1  1462          20         3        81.00    14267       1      2         0
# 2  1463          60         3        74.00    13830       1      2         0
# 3  1464          60         3        78.00     9978       1      2         0
# 4  1465         120         3        43.00     5005       1      2         0
#
#    LandContour  Utilities  ...  ScreenPorch  PoolArea  PoolQC  Fence  \
# 0            3          0  ...          120         0       2      2
# 1            3          0  ...            0         0       2      4
# 2            3          0  ...            0         0       2      2
# 3            3          0  ...            0         0       2      4
# 4            1          0  ...          144         0       2      4
#
#    MiscFeature  MiscVal  MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
df_holdout.drop('Id',axis=1,inplace=True)

# %%
df_holdout.shape
# Out:
# (1459, 79)

# %%
len(beta_coeff)
# Out:
# 79

# %%
predictions=np.multiply(df_holdout.values,beta_coeff).sum(axis=1)

# %%
test.shape
# Out:
# (1459,)

# %%
sumbission_file=pd.DataFrame(predictions)

# %%
sumbission_file.to_excel("sumbission_file.xlsx")

# %%
pwd
# Out:
# 'C:\\Users\\hh'
