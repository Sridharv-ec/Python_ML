# %%
import pandas as pd
import numpy as np
from pandas.io.json import json_normalize
import os

# %%
def load_df(csv_path='../input/train.csv', nrows=None):
    JSON_COLUMNS = [ 'device', 'geoNetwork', 'totals', 'trafficSource']
    
    df = pd.read_csv(csv_path, 
                     converters={column: json.loads for column in JSON_COLUMNS}, 
                     dtype={'fullVisitorId': 'str'}, # Important!!
                     nrows=nrows)
    
    for column in JSON_COLUMNS:
        column_as_df = json_normalize(df[column])
        column_as_df.columns = [f"{column}.{subcolumn}" for subcolumn in column_as_df.columns]
        df = df.drop(column, axis=1).merge(column_as_df, right_index=True, left_index=True)
    print(f"Loaded {os.path.basename(csv_path)}. Shape: {df.shape}")
    return df

# %%
training_sample_dataset = pd.read_csv("C:\\Sridhar\\AI_ML\\Algorithms\\datasets\\ga-customer-revenue-prediction\\training_sample.csv")

# %%
training_sample_dataset.shape
# Out:
# (40000, 14)

# %%
test_sample_dataset = pd.read_csv("C:\\Sridhar\\AI_ML\\Algorithms\\datasets\\ga-customer-revenue-prediction\\test_sample.csv")

# %%
test_sample_dataset.shape
# Out:
# (40000, 14)

# %%
 def memoryManagement(base_dataset):
    """ iterate through all the columns of a dataframe and modify the data type
        to reduce memory usage.        
    """
    df=base_dataset
    start_mem = df.memory_usage().sum() / 1024**2
    print('Memory usage of dataframe is {:.2f} MB'.format(start_mem))

    for col in df.columns:
        col_type = df[col].dtype

        if col_type != object:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)  
            else:
                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)
        else:
            df[col] = df[col].astype('category')

    end_mem = df.memory_usage().sum() / 1024**2
    print('Memory usage after optimization is: {:.2f} MB'.format(end_mem))
    print('Decreased by {:.1f}%'.format(100 * (start_mem - end_mem) / start_mem))    
    return df

# %%
training_sample = memoryManagement(training_sample_dataset)
# Out:
# Memory usage of dataframe is 4.27 MB
# Memory usage after optimization is: 5.15 MB
# Decreased by -20.5%

# %%
test_sample = memoryManagement(test_sample_dataset)
# Out:
# Memory usage of dataframe is 4.27 MB
# Memory usage after optimization is: 3.93 MB
# Decreased by 7.9%

# %%
training_sample_dataset_1 = training_sample_dataset[0:20000]
test_sample_dataset_1 = test_sample_dataset[0:20000]

# %%
training_sample = training_sample_dataset[0:20000]
test_sample = test_sample[0:20000]

# %%
training_sample_dataset_1.to_csv("C:\\Sridhar\\AI_ML\\Algorithms\\datasets\\ga-customer-revenue-prediction\\df_training.csv")

# %%
training_sample_dataset_1 = load_df("C:\\Sridhar\\AI_ML\\Algorithms\\datasets\\ga-customer-revenue-prediction\\df_training.csv")
# Out:
# Loaded df_training.csv. Shape: (20000, 58)

# %%
training_sample_dataset_1.head()
# Out:
#    Unnamed: 0 channelGrouping                              customDimensions  \
# 0           0  Organic Search             [{'index': '4', 'value': 'EMEA'}]
# 1           1        Referral    [{'index': '4', 'value': 'North America'}]
# 2           2          Direct    [{'index': '4', 'value': 'North America'}]
# 3           3  Organic Search             [{'index': '4', 'value': 'EMEA'}]
# 4           4  Organic Search  [{'index': '4', 'value': 'Central America'}]
#
#        date                                             device  \
# 0  20171016  {"browser": "Firefox", "browserVersion": "not ...
# 1  20171016  {"browser": "Chrome", "browserVersion": "not a...
# 2  20171016  {"browser": "Chrome", "browserVersion": "not a...
# 3  20171016  {"browser": "Chrome", "browserVersion": "not a...
# 4  20171016  {"browser": "Chrome", "browserVersion": "not a...
#
#          fullVisitorId                                         geoNetwork  \
# 0  3162355547410993243  {"continent": "Europe", "subContinent": "Weste...
# 1  8934116514970143966  {"continent": "Americas", "subContinent": "Nor...
# 2  7992466427990357681  {"continent": "Americas", "subContinent": "Nor...
# 3  9075655783635761930  {"continent": "Asia", "subContinent": "Western...
# 4  6960673291025684308  {"continent": "Americas", "subContinent": "Cen...
#
#                                                 hits  socialEngagementType  \
# 0  [{'hitNumber': '1', 'time': '0', 'hour': '17',...  Not Socially Engaged
# 1  [{'hitNumber': '1', 'time': '0', 'hour': '10',...  Not Socially Engaged
# 2  [{'hitNumber': '1', 'time': '0', 'hour': '17',...  Not Socially Engaged
# 3  [{'hitNumber': '1', 'time': '0', 'hour': '9', ...  Not Socially Engaged
# 4  [{'hitNumber': '1', 'time': '0', 'hour': '14',...  Not Socially Engaged
#
#                                               totals  \
# 0  {"visits": "1", "hits": "1", "pageviews": "1",...
# 1  {"visits": "1", "hits": "2", "pageviews": "2",...
# 2  {"visits": "1", "hits": "2", "pageviews": "2",...
# 3  {"visits": "1", "hits": "2", "pageviews": "2",...
# 4  {"visits": "1", "hits": "2", "pageviews": "2",...
#
#                                        trafficSource     visitId  visitNumber  \
# 0  {"campaign": "(not set)", "source": "google", ...  1508198450            1
# 1  {"referralPath": "/a/google.com/transportation...  1508176307            6
# 2  {"campaign": "(not set)", "source": "(direct)"...  1508201613            1
# 3  {"campaign": "(not set)", "source": "google", ...  1508169851            1
# 4  {"campaign": "(not set)", "source": "google", ...  1508190552            1
#
#    visitStartTime
# 0      1508198450
# 1      1508176307
# 2      1508201613
# 3      1508169851
# 4      1508190552

# %%
training_sample_dataset_1.drop(["customDimensions","hits","Unnamed: 0"],axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-37-daf868c44ff1> in <module>
# ----> 1 training_sample_dataset_1.drop(["customDimensions","hits","Unnamed: 0"],axis=1,inplace=True)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3938                                            index=index, columns=columns,
#    3939                                            level=level, inplace=inplace,
# -> 3940                                            errors=errors)
#    3941
#    3942     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3778         for axis, labels in axes.items():
#    3779             if labels is not None:
# -> 3780                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3781
#    3782         if inplace:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    3810                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3811             else:
# -> 3812                 new_axis = axis.drop(labels, errors=errors)
#    3813             result = self.reindex(**{axis_name: new_axis})
#    3814
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    4963             if errors != 'ignore':
#    4964                 raise KeyError(
# -> 4965                     '{} not found in axis'.format(labels[mask]))
#    4966             indexer = indexer[~mask]
#    4967         return self.delete(indexer)
#
# KeyError: "['customDimensions' 'hits'] not found in axis"

# %%
training_sample_dataset_1.head()
# Out:
#   channelGrouping      date  \
# 0  Organic Search  20171016
# 1        Referral  20171016
# 2          Direct  20171016
# 3  Organic Search  20171016
# 4  Organic Search  20171016
#
#                                               device        fullVisitorId  \
# 0  {"browser": "Firefox", "browserVersion": "not ...  3162355547410993243
# 1  {"browser": "Chrome", "browserVersion": "not a...  8934116514970143966
# 2  {"browser": "Chrome", "browserVersion": "not a...  7992466427990357681
# 3  {"browser": "Chrome", "browserVersion": "not a...  9075655783635761930
# 4  {"browser": "Chrome", "browserVersion": "not a...  6960673291025684308
#
#                                           geoNetwork  socialEngagementType  \
# 0  {"continent": "Europe", "subContinent": "Weste...  Not Socially Engaged
# 1  {"continent": "Americas", "subContinent": "Nor...  Not Socially Engaged
# 2  {"continent": "Americas", "subContinent": "Nor...  Not Socially Engaged
# 3  {"continent": "Asia", "subContinent": "Western...  Not Socially Engaged
# 4  {"continent": "Americas", "subContinent": "Cen...  Not Socially Engaged
#
#                                               totals  \
# 0  {"visits": "1", "hits": "1", "pageviews": "1",...
# 1  {"visits": "1", "hits": "2", "pageviews": "2",...
# 2  {"visits": "1", "hits": "2", "pageviews": "2",...
# 3  {"visits": "1", "hits": "2", "pageviews": "2",...
# 4  {"visits": "1", "hits": "2", "pageviews": "2",...
#
#                                        trafficSource     visitId  visitNumber  \
# 0  {"campaign": "(not set)", "source": "google", ...  1508198450            1
# 1  {"referralPath": "/a/google.com/transportation...  1508176307            6
# 2  {"campaign": "(not set)", "source": "(direct)"...  1508201613            1
# 3  {"campaign": "(not set)", "source": "google", ...  1508169851            1
# 4  {"campaign": "(not set)", "source": "google", ...  1508190552            1
#
#    visitStartTime
# 0      1508198450
# 1      1508176307
# 2      1508201613
# 3      1508169851
# 4      1508190552

# %%
test_sample_dataset_1.to_csv("C:\\Sridhar\\AI_ML\\Algorithms\\datasets\\ga-customer-revenue-prediction\\df_test.csv")

# %%
test_sample_dataset_1 = load_df("C:\\Sridhar\\AI_ML\\Algorithms\\datasets\\ga-customer-revenue-prediction\\df_test.csv")
# Out:
# Loaded df_test.csv. Shape: (20000, 61)

# %%
test_sample_dataset_1.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1 channelGrouping  \
# 0           0             0  Organic Search
# 1           1             1          Direct
# 2           2             2  Organic Search
# 3           3             3          Direct
# 4           4             4  Organic Search
#
#                              customDimensions      date  fullVisitorId  \
# 0           [{'index': '4', 'value': 'APAC'}]  20180511   7.460955e+18
# 1  [{'index': '4', 'value': 'North America'}]  20180511  4.6025244e+17
# 2  [{'index': '4', 'value': 'North America'}]  20180511  3.4618085e+18
# 3  [{'index': '4', 'value': 'North America'}]  20180511  9.7512944e+17
# 4  [{'index': '4', 'value': 'North America'}]  20180511   8.381673e+18
#
#                                                 hits  socialEngagementType  \
# 0  [{'hitNumber': '1', 'time': '0', 'hour': '21',...  Not Socially Engaged
# 1  [{'hitNumber': '1', 'time': '0', 'hour': '11',...  Not Socially Engaged
# 2  [{'hitNumber': '1', 'time': '0', 'hour': '12',...  Not Socially Engaged
# 3  [{'hitNumber': '1', 'time': '0', 'hour': '23',...  Not Socially Engaged
# 4  [{'hitNumber': '1', 'time': '0', 'hour': '10',...  Not Socially Engaged
#
#       visitId  visitNumber  ...  trafficSource.adwordsClickInfo.gclId  \
# 0  1526099341            2  ...                                   NaN
# 1  1526064483          166  ...                                   NaN
# 2  1526067157            2  ...                                   NaN
# 3  1526107551            4  ...                                   NaN
# 4  1526060254            1  ...                                   NaN
#
#   trafficSource.adwordsClickInfo.isVideoAd  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#   trafficSource.adwordsClickInfo.page trafficSource.adwordsClickInfo.slot  \
# 0                                 NaN                                 NaN
# 1                                 NaN                                 NaN
# 2                                 NaN                                 NaN
# 3                                 NaN                                 NaN
# 4                                 NaN                                 NaN
#
#   trafficSource.campaign trafficSource.isTrueDirect  trafficSource.keyword  \
# 0              (not set)                       True         (not provided)
# 1              (not set)                       True              (not set)
# 2              (not set)                       True         (not provided)
# 3              (not set)                       True              (not set)
# 4              (not set)                        NaN         (not provided)
#
#   trafficSource.medium trafficSource.referralPath trafficSource.source
# 0              organic                  (not set)               google
# 1               (none)                  (not set)             (direct)
# 2              organic                  (not set)               google
# 3               (none)                  (not set)             (direct)
# 4              organic                  (not set)               google
#
# [5 rows x 61 columns]

# %%
test_sample_dataset_1.drop(["Unnamed: 0","Unnamed: 0.1","customDimensions","hits"],axis=1,inplace=True)

# %%
test_sample_dataset_1.head()
# Out:
#   channelGrouping      date  fullVisitorId  socialEngagementType     visitId  \
# 0  Organic Search  20180511   7.460955e+18  Not Socially Engaged  1526099341
# 1          Direct  20180511  4.6025244e+17  Not Socially Engaged  1526064483
# 2  Organic Search  20180511  3.4618085e+18  Not Socially Engaged  1526067157
# 3          Direct  20180511  9.7512944e+17  Not Socially Engaged  1526107551
# 4  Organic Search  20180511   8.381673e+18  Not Socially Engaged  1526060254
#
#    visitNumber  visitStartTime     device.browser  \
# 0            2      1526099341             Chrome
# 1          166      1526064483             Chrome
# 2            2      1526067157             Chrome
# 3            4      1526107551             Chrome
# 4            1      1526060254  Internet Explorer
#
#               device.browserSize          device.browserVersion  ...  \
# 0  not available in demo dataset  not available in demo dataset  ...
# 1  not available in demo dataset  not available in demo dataset  ...
# 2  not available in demo dataset  not available in demo dataset  ...
# 3  not available in demo dataset  not available in demo dataset  ...
# 4  not available in demo dataset  not available in demo dataset  ...
#
#   trafficSource.adwordsClickInfo.gclId  \
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
#
#   trafficSource.adwordsClickInfo.isVideoAd  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#    trafficSource.adwordsClickInfo.page trafficSource.adwordsClickInfo.slot  \
# 0                                  NaN                                 NaN
# 1                                  NaN                                 NaN
# 2                                  NaN                                 NaN
# 3                                  NaN                                 NaN
# 4                                  NaN                                 NaN
#
#   trafficSource.campaign trafficSource.isTrueDirect trafficSource.keyword  \
# 0              (not set)                       True        (not provided)
# 1              (not set)                       True             (not set)
# 2              (not set)                       True        (not provided)
# 3              (not set)                       True             (not set)
# 4              (not set)                        NaN        (not provided)
#
#   trafficSource.medium trafficSource.referralPath trafficSource.source
# 0              organic                  (not set)               google
# 1               (none)                  (not set)             (direct)
# 2              organic                  (not set)               google
# 3               (none)                  (not set)             (direct)
# 4              organic                  (not set)               google
#
# [5 rows x 57 columns]

# %%
training_sample_dataset_1.shape,test_sample_dataset_1.shape
# Out:
# ((20000, 58), (20000, 57))

# %%
training_sample_dataset_1.columns
# Out:
# Index(['Unnamed: 0', 'channelGrouping', 'date', 'fullVisitorId',
#        'socialEngagementType', 'visitId', 'visitNumber', 'visitStartTime',
#        'device.browser', 'device.browserSize', 'device.browserVersion',
#        'device.deviceCategory', 'device.flashVersion', 'device.isMobile',
#        'device.language', 'device.mobileDeviceBranding',
#        'device.mobileDeviceInfo', 'device.mobileDeviceMarketingName',
#        'device.mobileDeviceModel', 'device.mobileInputSelector',
#        'device.operatingSystem', 'device.operatingSystemVersion',
#        'device.screenColors', 'device.screenResolution', 'geoNetwork.city',
#        'geoNetwork.cityId', 'geoNetwork.continent', 'geoNetwork.country',
#        'geoNetwork.latitude', 'geoNetwork.longitude', 'geoNetwork.metro',
#        'geoNetwork.networkDomain', 'geoNetwork.networkLocation',
#        'geoNetwork.region', 'geoNetwork.subContinent', 'totals.bounces',
#        'totals.hits', 'totals.newVisits', 'totals.pageviews',
#        'totals.sessionQualityDim', 'totals.timeOnSite',
#        'totals.totalTransactionRevenue', 'totals.transactionRevenue',
#        'totals.transactions', 'totals.visits', 'trafficSource.adContent',
#        'trafficSource.adwordsClickInfo.adNetworkType',
#        'trafficSource.adwordsClickInfo.criteriaParameters',
#        'trafficSource.adwordsClickInfo.gclId',
#        'trafficSource.adwordsClickInfo.isVideoAd',
#        'trafficSource.adwordsClickInfo.page',
#        'trafficSource.adwordsClickInfo.slot', 'trafficSource.campaign',
#        'trafficSource.isTrueDirect', 'trafficSource.keyword',
#        'trafficSource.medium', 'trafficSource.referralPath',
#        'trafficSource.source'],
#       dtype='object')

# %%
(training_sample_dataset_1.isna().sum()/training_sample_dataset_1.shape[0])*100
# Out:
# Unnamed: 0                                            0.000
# channelGrouping                                       0.000
# date                                                  0.000
# fullVisitorId                                         0.000
# socialEngagementType                                  0.000
# visitId                                               0.000
# visitNumber                                           0.000
# visitStartTime                                        0.000
# device.browser                                        0.000
# device.browserSize                                    0.000
# device.browserVersion                                 0.000
# device.deviceCategory                                 0.000
# device.flashVersion                                   0.000
# device.isMobile                                       0.000
# device.language                                       0.000
# device.mobileDeviceBranding                           0.000
# device.mobileDeviceInfo                               0.000
# device.mobileDeviceMarketingName                      0.000
# device.mobileDeviceModel                              0.000
# device.mobileInputSelector                            0.000
# device.operatingSystem                                0.000
# device.operatingSystemVersion                         0.000
# device.screenColors                                   0.000
# device.screenResolution                               0.000
# geoNetwork.city                                       0.000
# geoNetwork.cityId                                     0.000
# geoNetwork.continent                                  0.000
# geoNetwork.country                                    0.000
# geoNetwork.latitude                                   0.000
# geoNetwork.longitude                                  0.000
# geoNetwork.metro                                      0.000
# geoNetwork.networkDomain                              0.000
# geoNetwork.networkLocation                            0.000
# geoNetwork.region                                     0.000
# geoNetwork.subContinent                               0.000
# totals.bounces                                       50.635
# totals.hits                                           0.000
# totals.newVisits                                     24.560
# totals.pageviews                                      0.005
# totals.sessionQualityDim                             54.400
# totals.timeOnSite                                    49.495
# totals.totalTransactionRevenue                       99.035
# totals.transactionRevenue                            99.035
# totals.transactions                                  99.020
# totals.visits                                         0.000
# trafficSource.adContent                              97.395
# trafficSource.adwordsClickInfo.adNetworkType         96.850
# trafficSource.adwordsClickInfo.criteriaParameters     0.000
# trafficSource.adwordsClickInfo.gclId                 96.835
# trafficSource.adwordsClickInfo.isVideoAd             96.850
# trafficSource.adwordsClickInfo.page                  96.850
# trafficSource.adwordsClickInfo.slot                  96.850
# trafficSource.campaign                                0.000
# trafficSource.isTrueDirect                           68.335
# trafficSource.keyword                                66.050
# trafficSource.medium                                  0.000
# trafficSource.referralPath                           69.480
# trafficSource.source                                  0.000
# dtype: float64

# %%
(test_sample_dataset_1.isna().sum()/test_sample_dataset_1.shape[0])*100
# Out:
# channelGrouping                                       0.000
# date                                                  0.000
# fullVisitorId                                         0.000
# socialEngagementType                                  0.000
# visitId                                               0.000
# visitNumber                                           0.000
# visitStartTime                                        0.000
# device.browser                                        0.000
# device.browserSize                                    0.000
# device.browserVersion                                 0.000
# device.deviceCategory                                 0.000
# device.flashVersion                                   0.000
# device.isMobile                                       0.000
# device.language                                       0.000
# device.mobileDeviceBranding                           0.000
# device.mobileDeviceInfo                               0.000
# device.mobileDeviceMarketingName                      0.000
# device.mobileDeviceModel                              0.000
# device.mobileInputSelector                            0.000
# device.operatingSystem                                0.000
# device.operatingSystemVersion                         0.000
# device.screenColors                                   0.000
# device.screenResolution                               0.000
# geoNetwork.city                                       0.000
# geoNetwork.cityId                                     0.000
# geoNetwork.continent                                  0.000
# geoNetwork.country                                    0.000
# geoNetwork.latitude                                   0.000
# geoNetwork.longitude                                  0.000
# geoNetwork.metro                                      0.000
# geoNetwork.networkDomain                              0.000
# geoNetwork.networkLocation                            0.000
# geoNetwork.region                                     0.000
# geoNetwork.subContinent                               0.000
# totals.bounces                                       53.915
# totals.hits                                           0.000
# totals.newVisits                                     28.155
# totals.pageviews                                      0.020
# totals.sessionQualityDim                              0.000
# totals.timeOnSite                                    46.235
# totals.totalTransactionRevenue                       99.105
# totals.transactionRevenue                            99.105
# totals.transactions                                  98.260
# totals.visits                                         0.000
# trafficSource.adContent                               0.000
# trafficSource.adwordsClickInfo.adNetworkType         98.205
# trafficSource.adwordsClickInfo.criteriaParameters     0.000
# trafficSource.adwordsClickInfo.gclId                 98.205
# trafficSource.adwordsClickInfo.isVideoAd             98.205
# trafficSource.adwordsClickInfo.page                  98.205
# trafficSource.adwordsClickInfo.slot                  98.205
# trafficSource.campaign                                0.000
# trafficSource.isTrueDirect                           63.170
# trafficSource.keyword                                 9.225
# trafficSource.medium                                  0.000
# trafficSource.referralPath                            0.000
# trafficSource.source                                  0.000
# dtype: float64

# %%
training_sample_dataset_1[training_sample_dataset_1['totals.transactionRevenue']!='NaN']
# Out:
#      channelGrouping      date        fullVisitorId  socialEngagementType  \
# 0     Organic Search  20171016  3162355547410993243  Not Socially Engaged
# 1           Referral  20171016  8934116514970143966  Not Socially Engaged
# 2             Direct  20171016  7992466427990357681  Not Socially Engaged
# 3     Organic Search  20171016  9075655783635761930  Not Socially Engaged
# 4     Organic Search  20171016  6960673291025684308  Not Socially Engaged
# 5           Referral  20171016  0166277907528479249  Not Socially Engaged
# 6           Referral  20171016  8349655975937271469  Not Socially Engaged
# 7     Organic Search  20171016  1332629902468998662  Not Socially Engaged
# 8     Organic Search  20171016   632878546807742341  Not Socially Engaged
# 9     Organic Search  20171016  1259490915281096752  Not Socially Engaged
# 10    Organic Search  20171016  7390444353235629134  Not Socially Engaged
# 11    Organic Search  20171016  1297236773919696722  Not Socially Engaged
# 12    Organic Search  20171016  5983987899933814948  Not Socially Engaged
# 13       Paid Search  20171016  6135613929977117121  Not Socially Engaged
# 14    Organic Search  20171016  7058083259448191057  Not Socially Engaged
# 15    Organic Search  20171016  9592294493127192752  Not Socially Engaged
# 16    Organic Search  20171016  6338477365942527347  Not Socially Engaged
# 17    Organic Search  20171016  5645448549604517238  Not Socially Engaged
# 18          Referral  20171016  4372943625982217246  Not Socially Engaged
# 19    Organic Search  20171016  6733325364864317729  Not Socially Engaged
# 20    Organic Search  20171016  6629331880108485577  Not Socially Engaged
# 21    Organic Search  20171016  2631312367160271984  Not Socially Engaged
# 22    Organic Search  20171016  0579247845938461901  Not Socially Engaged
# 23    Organic Search  20171016  6320181278650796626  Not Socially Engaged
# 24    Organic Search  20171016  5634653258298299672  Not Socially Engaged
# 25    Organic Search  20171016  0875141984250977091  Not Socially Engaged
# 26    Organic Search  20171016  3784396588165854095  Not Socially Engaged
# 27    Organic Search  20171016  7979131263881451334  Not Socially Engaged
# 28    Organic Search  20171016  5081271797474179310  Not Socially Engaged
# 29    Organic Search  20171016   451521411412093630  Not Socially Engaged
# ...              ...       ...                  ...                   ...
# 4970          Social  20160902  1901408834005459311  Not Socially Engaged
# 4971          Social  20160902  2367513634685845393  Not Socially Engaged
# 4972          Social  20160902  1546042474253670433  Not Socially Engaged
# 4973          Social  20160902  4088722376479733700  Not Socially Engaged
# 4974          Social  20160902  5596428489783433578  Not Socially Engaged
# 4975          Social  20160902  4296739797433208559  Not Socially Engaged
# 4976          Social  20160902  4401955184990005304  Not Socially Engaged
# 4977          Social  20160902  7828660039243545172  Not Socially Engaged
# 4978          Social  20160902  6769074722524595770  Not Socially Engaged
# 4979          Social  20160902   172193675909095351  Not Socially Engaged
# 4980          Social  20160902  6341513101646007598  Not Socially Engaged
# 4981          Social  20160902  9837365208950999507  Not Socially Engaged
# 4982          Social  20160902  8515504557321972642  Not Socially Engaged
# 4983          Social  20160902  4581528597568750612  Not Socially Engaged
# 4984          Social  20160902  5519418894572985498  Not Socially Engaged
# 4985          Social  20160902  5612660679067181681  Not Socially Engaged
# 4986          Social  20160902  5539483663485419281  Not Socially Engaged
# 4987          Social  20160902  0841526407431270881  Not Socially Engaged
# 4988          Social  20160902  7731434453828888129  Not Socially Engaged
# 4989          Social  20160902   299622574247207177  Not Socially Engaged
# 4990          Social  20160902  4509613564711907102  Not Socially Engaged
# 4991          Social  20160902  8437456138508820569  Not Socially Engaged
# 4992          Social  20160902  9527721973848603792  Not Socially Engaged
# 4993          Social  20160902  3012862681568602828  Not Socially Engaged
# 4994          Social  20160902  2677945190980017269  Not Socially Engaged
# 4995          Social  20160902  1104066560809104939  Not Socially Engaged
# 4996          Social  20160902  8303391855540542517  Not Socially Engaged
# 4997          Social  20160902   310991381213284761  Not Socially Engaged
# 4998          Social  20160902  1477136983194262190  Not Socially Engaged
# 4999          Social  20160902  9904382541062860503  Not Socially Engaged
#
#          visitId  visitNumber  visitStartTime     device.browser  \
# 0     1508198450            1      1508198450            Firefox
# 1     1508176307            6      1508176307             Chrome
# 2     1508201613            1      1508201613             Chrome
# 3     1508169851            1      1508169851             Chrome
# 4     1508190552            1      1508190552             Chrome
# 5     1508196701            1      1508196701             Chrome
# 6     1508152478            1      1508152478             Chrome
# 7     1508206208            1      1508206208             Chrome
# 8     1508207516            1      1508207516             Chrome
# 9     1508165159            2      1508165159             Safari
# 10    1508157285            1      1508157285             Chrome
# 11    1508160120            1      1508160120             Safari
# 12    1508177658            1      1508177658             Safari
# 13    1508166431           10      1508166431             Safari
# 14    1508174145            1      1508174145             Chrome
# 15    1508197277            1      1508197277             Safari
# 16    1508177911            1      1508177911         UC Browser
# 17    1508153337            1      1508153337             Safari
# 18    1508160406            1      1508160406             Safari
# 19    1508160304            1      1508160304             Chrome
# 20    1508142274            1      1508142274            Firefox
# 21    1508170914            1      1508170914             Chrome
# 22    1508165231            1      1508165231             Chrome
# 23    1508167897            1      1508167897             Chrome
# 24    1508150872            3      1508150872             Chrome
# 25    1508223135            1      1508223135             Chrome
# 26    1508203074            1      1508203074             Chrome
# 27    1508183432            1      1508183432             Chrome
# 28    1508179019            1      1508179019  Internet Explorer
# 29    1508160016            3      1508160016             Chrome
# ...          ...          ...             ...                ...
# 4970  1472833132            1      1472833132             Chrome
# 4971  1472830822            1      1472830822            Firefox
# 4972  1472800856            1      1472800856             Chrome
# 4973  1472829232            1      1472829232             Safari
# 4974  1472837198            1      1472837198             Chrome
# 4975  1472862562            1      1472862562             Chrome
# 4976  1472865759            1      1472865759             Chrome
# 4977  1472867561            1      1472867561             Chrome
# 4978  1472864490            1      1472864490             Chrome
# 4979  1472817928            1      1472817928             Chrome
# 4980  1472807109            1      1472807109             Chrome
# 4981  1472829478            1      1472829478             Safari
# 4982  1472845513            1      1472845513             Safari
# 4983  1472832371            2      1472832371             Chrome
# 4984  1472863257            1      1472863257             Safari
# 4985  1472811005            1      1472811005  Internet Explorer
# 4986  1472849491            1      1472849491             Safari
# 4987  1472846269            1      1472846269             Chrome
# 4988  1472852054            1      1472852054             Chrome
# 4989  1472858854            1      1472858854         Opera Mini
# 4990  1472826810            1      1472826810             Safari
# 4991  1472854500            1      1472854500             Safari
# 4992  1472881312            1      1472881312          YaBrowser
# 4993  1472822165            1      1472822165             Chrome
# 4994  1472817905            1      1472817905             Safari
# 4995  1472830419            1      1472830419             Safari
# 4996  1472807052            1      1472807052             Chrome
# 4997  1472835958            1      1472835958             Safari
# 4998  1472808377            1      1472808377             Safari
# 4999  1472847043            1      1472847043             Safari
#
#                  device.browserSize          device.browserVersion  ...  \
# 0     not available in demo dataset  not available in demo dataset  ...
# 1     not available in demo dataset  not available in demo dataset  ...
# 2     not available in demo dataset  not available in demo dataset  ...
# 3     not available in demo dataset  not available in demo dataset  ...
# 4     not available in demo dataset  not available in demo dataset  ...
# 5     not available in demo dataset  not available in demo dataset  ...
# 6     not available in demo dataset  not available in demo dataset  ...
# 7     not available in demo dataset  not available in demo dataset  ...
# 8     not available in demo dataset  not available in demo dataset  ...
# 9     not available in demo dataset  not available in demo dataset  ...
# 10    not available in demo dataset  not available in demo dataset  ...
# 11    not available in demo dataset  not available in demo dataset  ...
# 12    not available in demo dataset  not available in demo dataset  ...
# 13    not available in demo dataset  not available in demo dataset  ...
# 14    not available in demo dataset  not available in demo dataset  ...
# 15    not available in demo dataset  not available in demo dataset  ...
# 16    not available in demo dataset  not available in demo dataset  ...
# 17    not available in demo dataset  not available in demo dataset  ...
# 18    not available in demo dataset  not available in demo dataset  ...
# 19    not available in demo dataset  not available in demo dataset  ...
# 20    not available in demo dataset  not available in demo dataset  ...
# 21    not available in demo dataset  not available in demo dataset  ...
# 22    not available in demo dataset  not available in demo dataset  ...
# 23    not available in demo dataset  not available in demo dataset  ...
# 24    not available in demo dataset  not available in demo dataset  ...
# 25    not available in demo dataset  not available in demo dataset  ...
# 26    not available in demo dataset  not available in demo dataset  ...
# 27    not available in demo dataset  not available in demo dataset  ...
# 28    not available in demo dataset  not available in demo dataset  ...
# 29    not available in demo dataset  not available in demo dataset  ...
# ...                             ...                            ...  ...
# 4970  not available in demo dataset  not available in demo dataset  ...
# 4971  not available in demo dataset  not available in demo dataset  ...
# 4972  not available in demo dataset  not available in demo dataset  ...
# 4973  not available in demo dataset  not available in demo dataset  ...
# 4974  not available in demo dataset  not available in demo dataset  ...
# 4975  not available in demo dataset  not available in demo dataset  ...
# 4976  not available in demo dataset  not available in demo dataset  ...
# 4977  not available in demo dataset  not available in demo dataset  ...
# 4978  not available in demo dataset  not available in demo dataset  ...
# 4979  not available in demo dataset  not available in demo dataset  ...
# 4980  not available in demo dataset  not available in demo dataset  ...
# 4981  not available in demo dataset  not available in demo dataset  ...
# 4982  not available in demo dataset  not available in demo dataset  ...
# 4983  not available in demo dataset  not available in demo dataset  ...
# 4984  not available in demo dataset  not available in demo dataset  ...
# 4985  not available in demo dataset  not available in demo dataset  ...
# 4986  not available in demo dataset  not available in demo dataset  ...
# 4987  not available in demo dataset  not available in demo dataset  ...
# 4988  not available in demo dataset  not available in demo dataset  ...
# 4989  not available in demo dataset  not available in demo dataset  ...
# 4990  not available in demo dataset  not available in demo dataset  ...
# 4991  not available in demo dataset  not available in demo dataset  ...
# 4992  not available in demo dataset  not available in demo dataset  ...
# 4993  not available in demo dataset  not available in demo dataset  ...
# 4994  not available in demo dataset  not available in demo dataset  ...
# 4995  not available in demo dataset  not available in demo dataset  ...
# 4996  not available in demo dataset  not available in demo dataset  ...
# 4997  not available in demo dataset  not available in demo dataset  ...
# 4998  not available in demo dataset  not available in demo dataset  ...
# 4999  not available in demo dataset  not available in demo dataset  ...
#
#      trafficSource.adwordsClickInfo.gclId  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
# 5                                     NaN
# 6                                     NaN
# 7                                     NaN
# 8                                     NaN
# 9                                     NaN
# 10                                    NaN
# 11                                    NaN
# 12                                    NaN
# 13                                    NaN
# 14                                    NaN
# 15                                    NaN
# 16                                    NaN
# 17                                    NaN
# 18                                    NaN
# 19                                    NaN
# 20                                    NaN
# 21                                    NaN
# 22                                    NaN
# 23                                    NaN
# 24                                    NaN
# 25                                    NaN
# 26                                    NaN
# 27                                    NaN
# 28                                    NaN
# 29                                    NaN
# ...                                   ...
# 4970                                  NaN
# 4971                                  NaN
# 4972                                  NaN
# 4973                                  NaN
# 4974                                  NaN
# 4975                                  NaN
# 4976                                  NaN
# 4977                                  NaN
# 4978                                  NaN
# 4979                                  NaN
# 4980                                  NaN
# 4981                                  NaN
# 4982                                  NaN
# 4983                                  NaN
# 4984                                  NaN
# 4985                                  NaN
# 4986                                  NaN
# 4987                                  NaN
# 4988                                  NaN
# 4989                                  NaN
# 4990                                  NaN
# 4991                                  NaN
# 4992                                  NaN
# 4993                                  NaN
# 4994                                  NaN
# 4995                                  NaN
# 4996                                  NaN
# 4997                                  NaN
# 4998                                  NaN
# 4999                                  NaN
#
#      trafficSource.adwordsClickInfo.isVideoAd  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# 5                                         NaN
# 6                                         NaN
# 7                                         NaN
# 8                                         NaN
# 9                                         NaN
# 10                                        NaN
# 11                                        NaN
# 12                                        NaN
# 13                                        NaN
# 14                                        NaN
# 15                                        NaN
# 16                                        NaN
# 17                                        NaN
# 18                                        NaN
# 19                                        NaN
# 20                                        NaN
# 21                                        NaN
# 22                                        NaN
# 23                                        NaN
# 24                                        NaN
# 25                                        NaN
# 26                                        NaN
# 27                                        NaN
# 28                                        NaN
# 29                                        NaN
# ...                                       ...
# 4970                                      NaN
# 4971                                      NaN
# 4972                                      NaN
# 4973                                      NaN
# 4974                                      NaN
# 4975                                      NaN
# 4976                                      NaN
# 4977                                      NaN
# 4978                                      NaN
# 4979                                      NaN
# 4980                                      NaN
# 4981                                      NaN
# 4982                                      NaN
# 4983                                      NaN
# 4984                                      NaN
# 4985                                      NaN
# 4986                                      NaN
# 4987                                      NaN
# 4988                                      NaN
# 4989                                      NaN
# 4990                                      NaN
# 4991                                      NaN
# 4992                                      NaN
# 4993                                      NaN
# 4994                                      NaN
# 4995                                      NaN
# 4996                                      NaN
# 4997                                      NaN
# 4998                                      NaN
# 4999                                      NaN
#
#       trafficSource.adwordsClickInfo.page trafficSource.adwordsClickInfo.slot  \
# 0                                     NaN                                 NaN
# 1                                     NaN                                 NaN
# 2                                     NaN                                 NaN
# 3                                     NaN                                 NaN
# 4                                     NaN                                 NaN
# 5                                     NaN                                 NaN
# 6                                     NaN                                 NaN
# 7                                     NaN                                 NaN
# 8                                     NaN                                 NaN
# 9                                     NaN                                 NaN
# 10                                    NaN                                 NaN
# 11                                    NaN                                 NaN
# 12                                    NaN                                 NaN
# 13                                    NaN                                 NaN
# 14                                    NaN                                 NaN
# 15                                    NaN                                 NaN
# 16                                    NaN                                 NaN
# 17                                    NaN                                 NaN
# 18                                    NaN                                 NaN
# 19                                    NaN                                 NaN
# 20                                    NaN                                 NaN
# 21                                    NaN                                 NaN
# 22                                    NaN                                 NaN
# 23                                    NaN                                 NaN
# 24                                    NaN                                 NaN
# 25                                    NaN                                 NaN
# 26                                    NaN                                 NaN
# 27                                    NaN                                 NaN
# 28                                    NaN                                 NaN
# 29                                    NaN                                 NaN
# ...                                   ...                                 ...
# 4970                                  NaN                                 NaN
# 4971                                  NaN                                 NaN
# 4972                                  NaN                                 NaN
# 4973                                  NaN                                 NaN
# 4974                                  NaN                                 NaN
# 4975                                  NaN                                 NaN
# 4976                                  NaN                                 NaN
# 4977                                  NaN                                 NaN
# 4978                                  NaN                                 NaN
# 4979                                  NaN                                 NaN
# 4980                                  NaN                                 NaN
# 4981                                  NaN                                 NaN
# 4982                                  NaN                                 NaN
# 4983                                  NaN                                 NaN
# 4984                                  NaN                                 NaN
# 4985                                  NaN                                 NaN
# 4986                                  NaN                                 NaN
# 4987                                  NaN                                 NaN
# 4988                                  NaN                                 NaN
# 4989                                  NaN                                 NaN
# 4990                                  NaN                                 NaN
# 4991                                  NaN                                 NaN
# 4992                                  NaN                                 NaN
# 4993                                  NaN                                 NaN
# 4994                                  NaN                                 NaN
# 4995                                  NaN                                 NaN
# 4996                                  NaN                                 NaN
# 4997                                  NaN                                 NaN
# 4998                                  NaN                                 NaN
# 4999                                  NaN                                 NaN
#
#                                  trafficSource.campaign  \
# 0                                             (not set)
# 1                                             (not set)
# 2                                             (not set)
# 3                                             (not set)
# 4                                             (not set)
# 5                                             (not set)
# 6                                             (not set)
# 7                                             (not set)
# 8                                             (not set)
# 9                                             (not set)
# 10                                            (not set)
# 11                                            (not set)
# 12                                            (not set)
# 13    "google + redesign/Accessories March 17" All U...
# 14                                            (not set)
# 15                                            (not set)
# 16                                            (not set)
# 17                                            (not set)
# 18                                            (not set)
# 19                                            (not set)
# 20                                            (not set)
# 21                                            (not set)
# 22                                            (not set)
# 23                                            (not set)
# 24                                            (not set)
# 25                                            (not set)
# 26                                            (not set)
# 27                                            (not set)
# 28                                            (not set)
# 29                                            (not set)
# ...                                                 ...
# 4970                                          (not set)
# 4971                                          (not set)
# 4972                                          (not set)
# 4973                                          (not set)
# 4974                                          (not set)
# 4975                                          (not set)
# 4976                                          (not set)
# 4977                                          (not set)
# 4978                                          (not set)
# 4979                                          (not set)
# 4980                                          (not set)
# 4981                                          (not set)
# 4982                                          (not set)
# 4983                                          (not set)
# 4984                                          (not set)
# 4985                                          (not set)
# 4986                                          (not set)
# 4987                                          (not set)
# 4988                                          (not set)
# 4989                                          (not set)
# 4990                                          (not set)
# 4991                                          (not set)
# 4992                                          (not set)
# 4993                                          (not set)
# 4994                                          (not set)
# 4995                                          (not set)
# 4996                                          (not set)
# 4997                                          (not set)
# 4998                                          (not set)
# 4999                                          (not set)
#
#      trafficSource.isTrueDirect            trafficSource.keyword  \
# 0                           NaN                     water bottle
# 1                           NaN                              NaN
# 2                          True                              NaN
# 3                           NaN                   (not provided)
# 4                           NaN                   (not provided)
# 5                           NaN                              NaN
# 6                           NaN                              NaN
# 7                           NaN                   (not provided)
# 8                           NaN                   (not provided)
# 9                          True                   (not provided)
# 10                          NaN                   (not provided)
# 11                          NaN                   (not provided)
# 12                          NaN                   (not provided)
# 13                          NaN  (Remarketing/Content targeting)
# 14                          NaN                   (not provided)
# 15                          NaN                   (not provided)
# 16                          NaN                   (not provided)
# 17                          NaN                   (not provided)
# 18                          NaN                              NaN
# 19                          NaN                   (not provided)
# 20                          NaN                   (not provided)
# 21                          NaN                   (not provided)
# 22                          NaN                   (not provided)
# 23                          NaN                   (not provided)
# 24                          NaN                   (not provided)
# 25                          NaN                   (not provided)
# 26                          NaN                   (not provided)
# 27                          NaN                   (not provided)
# 28                          NaN                   (not provided)
# 29                         True                   (not provided)
# ...                         ...                              ...
# 4970                        NaN                              NaN
# 4971                        NaN                              NaN
# 4972                        NaN                              NaN
# 4973                        NaN                              NaN
# 4974                        NaN                              NaN
# 4975                        NaN                              NaN
# 4976                        NaN                              NaN
# 4977                        NaN                              NaN
# 4978                        NaN                              NaN
# 4979                        NaN                              NaN
# 4980                        NaN                              NaN
# 4981                        NaN                              NaN
# 4982                        NaN                              NaN
# 4983                       True                              NaN
# 4984                        NaN                              NaN
# 4985                        NaN                              NaN
# 4986                        NaN                              NaN
# 4987                        NaN                              NaN
# 4988                        NaN                              NaN
# 4989                        NaN                              NaN
# 4990                        NaN                              NaN
# 4991                        NaN                              NaN
# 4992                        NaN                              NaN
# 4993                        NaN                              NaN
# 4994                        NaN                              NaN
# 4995                        NaN                              NaN
# 4996                        NaN                              NaN
# 4997                        NaN                              NaN
# 4998                        NaN                              NaN
# 4999                        NaN                              NaN
#
#      trafficSource.medium                         trafficSource.referralPath  \
# 0                 organic                                                NaN
# 1                referral  /a/google.com/transportation/mtv-services/bike...
# 2                  (none)                                                NaN
# 3                 organic                                                NaN
# 4                 organic                                                NaN
# 5                  (none)                                        /offer/2145
# 6                referral  /a/google.com/nest-vision/dropcam-field-tester...
# 7                 organic                                                NaN
# 8                 organic                                                NaN
# 9                 organic                                                NaN
# 10                organic                                                NaN
# 11                organic                                                NaN
# 12                organic                                                NaN
# 13                    cpc                                                NaN
# 14                organic                                                NaN
# 15                organic                                                NaN
# 16                organic                                                NaN
# 17                organic                                                NaN
# 18               referral                                    /analytics/web/
# 19                organic                                                NaN
# 20                organic                                                NaN
# 21                organic                                                NaN
# 22                organic                                                NaN
# 23                organic                                                NaN
# 24                organic                                                NaN
# 25                organic                                                NaN
# 26                organic                                                NaN
# 27                organic                                                NaN
# 28                organic                                                NaN
# 29                organic                                                NaN
# ...                   ...                                                ...
# 4970             referral                                      /yt/about/es/
# 4971             referral                                      /yt/about/fr/
# 4972             referral                                      /yt/about/ru/
# 4973             referral                                      /yt/about/tr/
# 4974             referral                                   /yt/about/en-GB/
# 4975             referral                                   /yt/about/en-GB/
# 4976             referral                                   /yt/about/en-GB/
# 4977             referral                                   /yt/about/pt-BR/
# 4978             referral                                  /yt/about/es-419/
# 4979             referral                                      /yt/about/id/
# 4980             referral                                      /yt/about/ko/
# 4981             referral                                      /yt/about/it/
# 4982             referral                                      /yt/about/ar/
# 4983             referral                                      /yt/about/tr/
# 4984             referral                                   /yt/about/en-GB/
# 4985             referral                                      /yt/about/nl/
# 4986             referral                                      /yt/about/pl/
# 4987             referral                                      /yt/about/pl/
# 4988             referral                                      /yt/about/pl/
# 4989             referral                                      /yt/about/ar/
# 4990             referral                                      /yt/about/es/
# 4991             referral                                      /yt/about/es/
# 4992             referral                                      /yt/about/ru/
# 4993             referral                                      /yt/about/tr/
# 4994             referral                                      /yt/about/tr/
# 4995             referral                                      /yt/about/tr/
# 4996             referral                                      /yt/about/vi/
# 4997             referral                                  /yt/about/es-419/
# 4998             referral                                  /yt/about/es-419/
# 4999             referral                                  /yt/about/es-419/
#
#       trafficSource.source
# 0                   google
# 1         sites.google.com
# 2                 (direct)
# 3                   google
# 4                   google
# 5                 (direct)
# 6         sites.google.com
# 7                   google
# 8                   google
# 9                   google
# 10                  google
# 11                  google
# 12                  google
# 13                  google
# 14                  google
# 15                  google
# 16                  google
# 17                  google
# 18    analytics.google.com
# 19                  google
# 20                  google
# 21                  google
# 22                  google
# 23                  google
# 24                  google
# 25                  google
# 26                  google
# 27                  google
# 28                  google
# 29                  google
# ...                    ...
# 4970           youtube.com
# 4971           youtube.com
# 4972           youtube.com
# 4973           youtube.com
# 4974           youtube.com
# 4975           youtube.com
# 4976           youtube.com
# 4977           youtube.com
# 4978           youtube.com
# 4979           youtube.com
# 4980           youtube.com
# 4981           youtube.com
# 4982           youtube.com
# 4983           youtube.com
# 4984           youtube.com
# 4985           youtube.com
# 4986           youtube.com
# 4987           youtube.com
# 4988           youtube.com
# 4989           youtube.com
# 4990           youtube.com
# 4991           youtube.com
# 4992           youtube.com
# 4993           youtube.com
# 4994           youtube.com
# 4995           youtube.com
# 4996           youtube.com
# 4997           youtube.com
# 4998           youtube.com
# 4999           youtube.com
#
# [5000 rows x 57 columns]

# %%
def null_values(base_dataset):
    print(base_dataset.isna().sum())
    # null value percentage     
    null_value_table=(base_dataset.isna().sum()/base_dataset.shape[0])*100
    # null value percentage beyond threshold drop , else treat the columns 
    
    retained_columns=null_value_table[null_value_table<int(input())].index
    #if any variable as null value greater than input(like 30% of the data) 
    #value than those variable are consider as drop
    drop_columns=null_value_table[null_value_table>int(input())].index
    base_dataset.drop(drop_columns,axis=1,inplace=True)
    len(base_dataset.isna().sum().index)
    cont=base_dataset.describe().columns
    cat=[i for i in base_dataset.columns if i not in base_dataset.describe().columns]
    for i in cat:
        base_dataset[i].fillna(base_dataset[i].value_counts().index[0],inplace=True)
    for i in cont:
        base_dataset[i].fillna(base_dataset[i].median(),inplace=True)
    print(base_dataset.isna().sum())
    return base_dataset,cat,cont

# %%
train_dataset,train_cat,train_continuos = null_values(training_sample_dataset_1)
# Out:
# channelGrouping                                         0
# date                                                    0
# fullVisitorId                                           0
# socialEngagementType                                    0
# visitId                                                 0
# visitNumber                                             0
# visitStartTime                                          0
# device.browser                                          0
# device.browserSize                                      0
# device.browserVersion                                   0
# device.deviceCategory                                   0
# device.flashVersion                                     0
# device.isMobile                                         0
# device.language                                         0
# device.mobileDeviceBranding                             0
# device.mobileDeviceInfo                                 0
# device.mobileDeviceMarketingName                        0
# device.mobileDeviceModel                                0
# device.mobileInputSelector                              0
# device.operatingSystem                                  0
# device.operatingSystemVersion                           0
# device.screenColors                                     0
# device.screenResolution                                 0
# geoNetwork.city                                         0
# geoNetwork.cityId                                       0
# geoNetwork.continent                                    0
# geoNetwork.country                                      0
# geoNetwork.latitude                                     0
# geoNetwork.longitude                                    0
# geoNetwork.metro                                        0
# geoNetwork.networkDomain                                0
# geoNetwork.networkLocation                              0
# geoNetwork.region                                       0
# geoNetwork.subContinent                                 0
# totals.bounces                                       2463
# totals.hits                                             0
# totals.newVisits                                     1250
# totals.pageviews                                        0
# totals.sessionQualityDim                             2011
# totals.timeOnSite                                    2543
# totals.totalTransactionRevenue                       4949
# totals.transactionRevenue                            4949
# totals.transactions                                  4946
# totals.visits                                           0
# trafficSource.adContent                              4725
# trafficSource.adwordsClickInfo.adNetworkType         4628
# trafficSource.adwordsClickInfo.criteriaParameters       0
# trafficSource.adwordsClickInfo.gclId                 4627
# trafficSource.adwordsClickInfo.isVideoAd             4628
# trafficSource.adwordsClickInfo.page                  4628
# trafficSource.adwordsClickInfo.slot                  4628
# trafficSource.campaign                                  0
# trafficSource.isTrueDirect                           3415
# trafficSource.keyword                                2289
# trafficSource.medium                                    0
# trafficSource.referralPath                           3605
# trafficSource.source                                    0
# dtype: int64
# 30
# 30
# channelGrouping                                      0
# date                                                 0
# fullVisitorId                                        0
# socialEngagementType                                 0
# visitId                                              0
# visitNumber                                          0
# visitStartTime                                       0
# device.browser                                       0
# device.browserSize                                   0
# device.browserVersion                                0
# device.deviceCategory                                0
# device.flashVersion                                  0
# device.isMobile                                      0
# device.language                                      0
# device.mobileDeviceBranding                          0
# device.mobileDeviceInfo                              0
# device.mobileDeviceMarketingName                     0
# device.mobileDeviceModel                             0
# device.mobileInputSelector                           0
# device.operatingSystem                               0
# device.operatingSystemVersion                        0
# device.screenColors                                  0
# device.screenResolution                              0
# geoNetwork.city                                      0
# geoNetwork.cityId                                    0
# geoNetwork.continent                                 0
# geoNetwork.country                                   0
# geoNetwork.latitude                                  0
# geoNetwork.longitude                                 0
# geoNetwork.metro                                     0
# geoNetwork.networkDomain                             0
# geoNetwork.networkLocation                           0
# geoNetwork.region                                    0
# geoNetwork.subContinent                              0
# totals.hits                                          0
# totals.newVisits                                     0
# totals.pageviews                                     0
# totals.visits                                        0
# trafficSource.adwordsClickInfo.criteriaParameters    0
# trafficSource.campaign                               0
# trafficSource.medium                                 0
# trafficSource.source                                 0
# dtype: int64

# %%
test_dataset,test_cat,test_continuos = null_values(test_sample_dataset_1)
# Out:
# channelGrouping                                         0
# date                                                    0
# fullVisitorId                                           0
# socialEngagementType                                    0
# visitId                                                 0
# visitNumber                                             0
# visitStartTime                                          0
# device.browser                                          0
# device.browserSize                                      0
# device.browserVersion                                   0
# device.deviceCategory                                   0
# device.flashVersion                                     0
# device.isMobile                                         0
# device.language                                         0
# device.mobileDeviceBranding                             0
# device.mobileDeviceInfo                                 0
# device.mobileDeviceMarketingName                        0
# device.mobileDeviceModel                                0
# device.mobileInputSelector                              0
# device.operatingSystem                                  0
# device.operatingSystemVersion                           0
# device.screenColors                                     0
# device.screenResolution                                 0
# geoNetwork.city                                         0
# geoNetwork.cityId                                       0
# geoNetwork.continent                                    0
# geoNetwork.country                                      0
# geoNetwork.latitude                                     0
# geoNetwork.longitude                                    0
# geoNetwork.metro                                        0
# geoNetwork.networkDomain                                0
# geoNetwork.networkLocation                              0
# geoNetwork.region                                       0
# geoNetwork.subContinent                                 0
# totals.bounces                                       2638
# totals.hits                                             0
# totals.newVisits                                     1341
# totals.pageviews                                        1
# totals.sessionQualityDim                                0
# totals.timeOnSite                                    2371
# totals.totalTransactionRevenue                       4959
# totals.transactionRevenue                            4959
# totals.transactions                                  4862
# totals.visits                                           0
# trafficSource.adContent                                 0
# trafficSource.adwordsClickInfo.adNetworkType         4985
# trafficSource.adwordsClickInfo.criteriaParameters       0
# trafficSource.adwordsClickInfo.gclId                 4985
# trafficSource.adwordsClickInfo.isVideoAd             4985
# trafficSource.adwordsClickInfo.page                  4985
# trafficSource.adwordsClickInfo.slot                  4985
# trafficSource.campaign                                  0
# trafficSource.isTrueDirect                           3187
# trafficSource.keyword                                 278
# trafficSource.medium                                    0
# trafficSource.referralPath                              0
# trafficSource.source                                    0
# dtype: int64
# 30
# 30
# channelGrouping                                      0
# date                                                 0
# fullVisitorId                                        0
# socialEngagementType                                 0
# visitId                                              0
# visitNumber                                          0
# visitStartTime                                       0
# device.browser                                       0
# device.browserSize                                   0
# device.browserVersion                                0
# device.deviceCategory                                0
# device.flashVersion                                  0
# device.isMobile                                      0
# device.language                                      0
# device.mobileDeviceBranding                          0
# device.mobileDeviceInfo                              0
# device.mobileDeviceMarketingName                     0
# device.mobileDeviceModel                             0
# device.mobileInputSelector                           0
# device.operatingSystem                               0
# device.operatingSystemVersion                        0
# device.screenColors                                  0
# device.screenResolution                              0
# geoNetwork.city                                      0
# geoNetwork.cityId                                    0
# geoNetwork.continent                                 0
# geoNetwork.country                                   0
# geoNetwork.latitude                                  0
# geoNetwork.longitude                                 0
# geoNetwork.metro                                     0
# geoNetwork.networkDomain                             0
# geoNetwork.networkLocation                           0
# geoNetwork.region                                    0
# geoNetwork.subContinent                              0
# totals.hits                                          0
# totals.newVisits                                     0
# totals.pageviews                                     0
# totals.sessionQualityDim                             0
# totals.visits                                        0
# trafficSource.adContent                              0
# trafficSource.adwordsClickInfo.criteriaParameters    0
# trafficSource.campaign                               0
# trafficSource.keyword                                0
# trafficSource.medium                                 0
# trafficSource.referralPath                           0
# trafficSource.source                                 0
# dtype: int64

# %%
train_dataset.shape
# Out:
# (5000, 42)

# %%
test_dataset.shape
# Out:
# (5000, 46)

# %%
train_dataset['total.r']
